# %%
import pandas as pd

df = pd.read_csv("Minimum Wage Data.csv", encoding="latin")
df.to_csv("Minwage.csv", encoding= "utf-8")

# %%
df = pd.read_csv("Minwage.csv")
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# ...

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0     2.1    0.468   0.15625        1.65       1.0         1.40
# 1969      0.0     2.1    0.468   0.15625        1.65       1.0         1.40
# 1970      0.0     2.1    0.468   1.10000        1.65       1.0         1.60
# 1971      0.0     2.1    0.468   1.10000        1.65       1.0         1.60
# 1972      0.0     2.1    0.468   1.20000        1.65       1.0         1.85
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      1.25                  1.25      0.0  ...        0.0    0.0
# 1969      1.25                  1.25      0.0  ...        0.0    0.0
# 1970      1.25                  1.60      0.0  ...        0.0    0.0
# 1971      1.25                  1.60      0.0  ...        0.0    0.0
# 1972      1.60                  1.60      0.0  ...        0.0    1.4
#
# ...

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   5.274906   2.324415   4.193632    5.175472   4.253019
# std        0.0   2.424435   3.866388   2.374197    2.985101   3.041658
# min        0.0   2.100000   0.000000   0.156250    1.650000   1.000000
# 25%        0.0   3.850000   0.000000   2.700000    3.350000   1.900000
# 50%        0.0   4.750000   0.000000   4.250000    4.250000   3.000000
# 75%        0.0   7.150000   6.750000   6.250000    7.500000   6.850000
# max        0.0  10.190000  12.000000  10.000000   13.000000  12.000000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      5.194906   4.489623              5.250189   2.160943  ...
# std       2.809161   2.539010              3.462850   3.490073  ...
# ...

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.813187  0.981938    0.986455  0.970585
# Arizona         NaN  0.813187  1.000000  0.805781    0.853713  0.878803
# Arkansas        NaN  0.981938  0.805781  1.000000    0.981222  0.974544
# California      NaN  0.986455  0.853713  0.981222    1.000000  0.987726
#
#             Connecticut  Delaware  District of Columbia   Florida  ...  \
# Alabama             NaN       NaN                   NaN       NaN  ...
# Alaska         0.992234  0.971193              0.973326  0.834101  ...
# Arizona        0.827466  0.786208              0.860865  0.952754  ...
# Arkansas       0.980991  0.971062              0.976168  0.805780  ...
# California     0.992328  0.969744              0.982806  0.853217  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
issue_df = df[df['Department.Of.Labor.Cleaned.Low.Value']==0]
issue_df.head()
# Out:
#     Unnamed: 0  Year     State  State.Minimum.Wage  \
# 0            0  1968   Alabama                 0.0
# 9            9  1968   Florida                 0.0
# 10          10  1968   Georgia                 0.0
# 14          14  1968  Illinois                 0.0
# 16          16  1968      Iowa                 0.0
#
#     State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                               0.0                  1.15
# 9                               0.0                  1.15
# 10                              0.0                  1.15
# 14                              0.0                  1.15
# 16                              0.0                  1.15
#
#     Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                8.55                    1.15
# 9                                8.55                    1.15
# 10                               8.55                    1.15
# ...

# %%
issue_df["State"].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'U.S. Virgin Islands',
#        'Virginia', 'Arizona', 'Puerto Rico'], dtype=object)

# %%
import numpy as np

act_min_wage.replace(0, np.NaN).dropna(axis=1).corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000  0.981938    0.986455  0.970585     0.992234  0.971193
# Arkansas     0.981938  1.000000    0.981222  0.974544     0.980991  0.971062
# California   0.986455  0.981222    1.000000  0.987726     0.992328  0.969744
# Colorado     0.970585  0.974544    0.987726  1.000000     0.980025  0.968148
# Connecticut  0.992234  0.980991    0.992328  0.980025     1.000000  0.981611
#
#              District of Columbia      Guam    Hawaii     Idaho  ...  \
# Alaska                   0.973326  0.979386  0.986835  0.958666  ...
# Arkansas                 0.976168  0.975847  0.989265  0.951022  ...
# California               0.982806  0.967800  0.981436  0.946857  ...
# Colorado                 0.986274  0.961301  0.973284  0.942145  ...
# Connecticut              0.972706  0.976996  0.984969  0.963695  ...
#
#                Oregon  Pennsylvania  Rhode Island  South Dakota      Utah  \
# ...

# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr().head()

for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("We are missing something here")

# %%
group_issue = issue_df.groupby("State")

group_issue.get_group("Alabama").head()
# Out:
#      Unnamed: 0  Year    State  State.Minimum.Wage  \
# 0             0  1968  Alabama                 0.0
# 54           54  1969  Alabama                 0.0
# 108         108  1970  Alabama                 0.0
# 162         162  1971  Alabama                 0.0
# 216         216  1972  Alabama                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.0                  1.15
# 54                               0.0                  1.15
# 108                              0.0                  1.30
# 162                              0.0                  1.30
# 216                              0.0                  1.60
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                 8.55                    1.15
# 54                                8.11                    1.15
# 108                               8.67                    1.30
# ...

# %%
group_issue.get_group("Alabama")['Department.Of.Labor.Cleaned.Low.Value'].sum()
# Out:
# 0.0

# %%
for state,data in group_issue:
    if data['Department.Of.Labor.Cleaned.Low.Value'].sum() !=0.0:
        print("We missed something ")
